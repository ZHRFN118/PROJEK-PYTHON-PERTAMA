# %% [markdown]
# <a href="https://colab.research.google.com/github/ZHRFN118/PROJEK-PYTHON-PERTAMA/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Buat Array 2D
arr_2d = np.array([[1,2,3], [4,5,6]])

# Operasi matematik pantas!
print("Bentuk (Shape):", arr_2d.shape) # Output: (2,3)
print("Jumlah Paksi 0:", np.sum(arr_2d, axis=0))

# Buat senarai nombor automatik
nombor = np.arange(24).reshape(2,3,4)
# Out:
# Bentuk (Shape): (2, 3)
# Jumlah Paksi 0: [5 7 9]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100) # Guna NumPy
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax = plt.subplots() #Buat kanvas
ax.plot(x, y1, color='blue', label='Sin')
ax.plot(x, y2, color='red', label='Cos')

ax.set_title("Perbandingan Sin & Cos")
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# situasi
nama_buah = ['Epal', 'Oren', 'Lemon']
jualan = [10, 15, 5]

# Carta Palang
plt.bar(nama_buah, jualan)

# Tajuk dan label
plt.title('Penjualan Buah')
plt.xlabel('Buah-buahan')
plt.ylabel('Bilangan Jualan')

# Menampilkan grafik
plt.show()
